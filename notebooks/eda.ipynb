# %% [markdown]
# # Exploratory Analysis — D02
#
# What drives logistics delivery delays?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('data/shipment_delays.csv')
df.head()

# %%
df.describe(include='all')

# %%
target = 'delayed'
df[target].value_counts(normalize=True).plot(kind='bar', title='Target rate')
plt.tight_layout()
